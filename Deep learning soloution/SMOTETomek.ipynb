# %%
import numpy as np
np.random.seed(42)

import pandas as pd

import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import xgboost as xgb

# %%
df = pd.read_excel('preprocessed data.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0  sl.no.  \
# 0           0       1
# 1           1       2
# 2           2       3
# 3           3       4
# 4           4       5
#
#    0- Good Outcome/no recurrence\n1- Bad Outcome/recurrence  tumor size  \
# 0                                                  0                  2
# 1                                                  0                  1
# 2                                                  0                  1
# 3                                                  0                  1
# 4                                                  0                  1
#
#    node status of the tumor  Age of the patient  tumor grade  A%-M  AI-M  \
# 0                         1                  60            3     0   2.5
# 1                         1                  55            2    15   2.0
# 2                         1                  33            3     0   2.5
# 3                         1                  67            2     0   2.0
# 4                         1                  47            2     0   0.0
#
#    A%-C  ...  R%-C  U%-C  V%-C  W%-M  W%-C  ZA1%-M  ZA1%-C  ZB%-C  ZC%-C  \
# 0    70  ...    70    80    75    70    60      85      60     80     85
# 1    20  ...    75    80    75    80    60      85      60     80     80
# 2    70  ...    60    75    70    70    70      55      70     75     80
# 3    45  ...    70    75    60    45    70      60      70     75     80
# 4     0  ...    75    75    80    70    75      85      75     80     80
#
#    ZD%-C
# 0     70
# 1     80
# 2     75
# 3     80
# 4     80
#
# [5 rows x 87 columns]

# %%
X_res = df.iloc[:,3:].values
y_res = df.iloc[:,2].values

# %%
from imblearn.under_sampling import NearMiss
from imblearn.combine import SMOTETomek
# Out:
# Using TensorFlow backend.

# %%
os = SMOTETomek()
X_res,y_res = os.fit_sample(X_res,y_res)

# %%
y_res.shape
# Out:
# (382,)

# %%
X_res.shape
# Out:
# (382, 84)

# %%
df.describe()
# Out:
#        Unnamed: 0      sl.no.  \
# count  234.000000  234.000000
# mean   116.500000  117.500000
# std     67.694165   67.694165
# min      0.000000    1.000000
# 25%     58.250000   59.250000
# 50%    116.500000  117.500000
# 75%    174.750000  175.750000
# max    233.000000  234.000000
#
#        0- Good Outcome/no recurrence\n1- Bad Outcome/recurrence  tumor size  \
# count                                         234.000000         234.000000
# mean                                            0.183761           1.944444
# std                                             0.388119           0.525234
# min                                             0.000000           1.000000
# 25%                                             0.000000           2.000000
# 50%                                             0.000000           2.000000
# 75%                                             0.000000           2.000000
# max                                             1.000000           3.000000
#
#        node status of the tumor  Age of the patient  tumor grade        A%-M  \
# count                234.000000          234.000000   234.000000  234.000000
# mean                   0.705128           48.974359     2.598291    6.581197
# std                    0.670193           10.551294     0.533188   17.617168
# min                    0.000000           25.000000     1.000000    0.000000
# 25%                    0.000000           41.000000     2.000000    0.000000
# 50%                    1.000000           49.000000     3.000000    0.000000
# 75%                    1.000000           56.750000     3.000000    0.000000
# max                    3.000000           75.000000     3.000000   80.000000
#
#              AI-M        A%-C  ...        R%-C        U%-C        V%-C  \
# count  234.000000  234.000000  ...  234.000000  234.000000  234.000000
# mean     1.737179   29.102564  ...   73.846154   75.320513   71.559829
# std      0.849354   30.409335  ...    6.804587    6.232602    7.427955
# min      0.000000    0.000000  ...   60.000000   55.000000   50.000000
# 25%      1.500000    0.000000  ...   70.000000   70.000000   70.000000
# 50%      2.000000   20.000000  ...   75.000000   75.000000   70.000000
# 75%      2.000000   60.000000  ...   80.000000   80.000000   75.000000
# max      3.000000   80.000000  ...   90.000000   90.000000   90.000000
#
#              W%-M        W%-C      ZA1%-M      ZA1%-C       ZB%-C       ZC%-C  \
# count  234.000000  234.000000  234.000000  234.000000  234.000000  234.000000
# mean    69.401709   70.170940   74.615385   70.170940   72.264957   76.303419
# std     10.454528    8.957018    6.457316    8.957018    8.491241    5.851326
# min     40.000000   40.000000   55.000000   40.000000   50.000000   55.000000
# 25%     65.000000   65.000000   70.000000   65.000000   70.000000   71.250000
# 50%     70.000000   70.000000   75.000000   70.000000   70.000000   80.000000
# 75%     75.000000   78.750000   80.000000   78.750000   80.000000   80.000000
# max     95.000000   85.000000   90.000000   85.000000   85.000000   90.000000
#
#             ZD%-C
# count  234.000000
# mean    74.914530
# std      5.913646
# min     55.000000
# 25%     70.000000
# 50%     75.000000
# 75%     80.000000
# max     85.000000
#
# [8 rows x 87 columns]

# %%
# Principal component analysis
pca = PCA(n_components = 2)
pca_2d = pca.fit_transform(X_res)

# %%
plt.figure(figsize = (10, 10))
plt.scatter(pca_2d[:,0], pca_2d[:,1], c = y_res)
plt.title('PCA scatter plot')
plt.show()

# %%
perplexities = (2, 5, 10, 30, 50, 100)
plt.figure(figsize = (10, 10*len(perplexities)))
for i, perplex in enumerate(perplexities):
    print('perplexity: {}'.format(perplex))
    tsne = TSNE(n_components = 2, perplexity = perplex, n_iter = 1000, verbose = 1)
    tsne_2d = tsne.fit_transform(X_res)
    
    plt.subplot(int('{}1{}'.format(len(perplexities), i+1)))
    plt.title('t-SNE scatter plot, perplexity = {}'.format(perplex))
    plt.scatter(tsne_2d[:,0], tsne_2d[:,1], c = y_res)
plt.show()
# Out:
# perplexity: 2
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 382 samples in 0.001s...
# [t-SNE] Computed neighbors for 382 samples in 0.017s...
# [t-SNE] Computed conditional probabilities for sample 382 / 382
# [t-SNE] Mean sigma: 5.702568
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 81.739792
# [t-SNE] KL divergence after 1000 iterations: 0.575967
# perplexity: 5
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 382 samples in 0.001s...
# [t-SNE] Computed neighbors for 382 samples in 0.021s...
# [t-SNE] Computed conditional probabilities for sample 382 / 382
# [t-SNE] Mean sigma: 18.156441
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.321678
# [t-SNE] KL divergence after 1000 iterations: 0.754538
# perplexity: 10
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 382 samples in 0.002s...
# [t-SNE] Computed neighbors for 382 samples in 0.022s...
# [t-SNE] Computed conditional probabilities for sample 382 / 382
# [t-SNE] Mean sigma: 28.371022
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 78.224312
# [t-SNE] KL divergence after 1000 iterations: 0.799258
# perplexity: 30
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 382 samples in 0.002s...
# [t-SNE] Computed neighbors for 382 samples in 0.025s...
# [t-SNE] Computed conditional probabilities for sample 382 / 382
# [t-SNE] Mean sigma: 35.899921
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 69.373444
# [t-SNE] KL divergence after 1000 iterations: 0.762519
# perplexity: 50
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 382 samples in 0.001s...
# [t-SNE] Computed neighbors for 382 samples in 0.027s...
# [t-SNE] Computed conditional probabilities for sample 382 / 382
# [t-SNE] Mean sigma: 40.384873
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 66.010078
# [t-SNE] KL divergence after 1000 iterations: 0.669185
# perplexity: 100
# [t-SNE] Computing 301 nearest neighbors...
# [t-SNE] Indexed 382 samples in 0.000s...
# [t-SNE] Computed neighbors for 382 samples in 0.038s...
# [t-SNE] Computed conditional probabilities for sample 382 / 382
# [t-SNE] Mean sigma: 46.006843
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 60.322952
# [t-SNE] KL divergence after 1000 iterations: 0.511591

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_res,y_res, test_size = 0.1, random_state = 0)

# %%
# Deep learning Keras stuff
from keras.models import Sequential
from keras.layers import Dense, Activation

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)

model = Sequential()
model.add(Dense(32, input_dim = 84, init = 'uniform'))
model.add(Activation('relu'))
model.add(Dense(16, init = 'uniform'))
model.add(Activation('sigmoid'))
model.add(Dense(1, init = 'uniform'))

model.compile(loss = 'binary_crossentropy', optimizer = 'Adam', metrics = ['accuracy'])
model.fit(scaler.transform(X_train), y_train, nb_epoch = 20, batch_size = 10)
# Out:
# /home/nitin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(32, input_dim=84, kernel_initializer="uniform")`
#   # This is added back by InteractiveShellApp.init_path()
# /home/nitin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(16, kernel_initializer="uniform")`
#   del sys.path[0]
# /home/nitin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform")`
#   from ipykernel import kernelapp as app
# /home/nitin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Epoch 1/20
# 343/343 [==============================] - 0s 339us/step - loss: 7.6000 - accuracy: 0.5073
# Epoch 2/20
# 343/343 [==============================] - 0s 77us/step - loss: 7.6000 - accuracy: 0.5073
# Epoch 3/20
# 343/343 [==============================] - 0s 83us/step - loss: 7.6000 - accuracy: 0.5073
# Epoch 4/20
# 343/343 [==============================] - 0s 78us/step - loss: 7.6000 - accuracy: 0.5073
# Epoch 5/20
# 343/343 [==============================] - 0s 77us/step - loss: 7.6000 - accuracy: 0.5073
# Epoch 6/20
# 343/343 [==============================] - 0s 79us/step - loss: 7.6000 - accuracy: 0.5073
# Epoch 7/20
# 343/343 [==============================] - 0s 81us/step - loss: 7.6000 - accuracy: 0.5073
# Epoch 8/20
# 343/343 [==============================] - 0s 76us/step - loss: 7.6000 - accuracy: 0.5073
# Epoch 9/20
# 343/343 [==============================] - 0s 71us/step - loss: 7.6000 - accuracy: 0.5073
# Epoch 10/20
# 343/343 [==============================] - 0s 76us/step - loss: 7.6000 - accuracy: 0.5073
# Epoch 11/20
# 343/343 [==============================] - 0s 73us/step - loss: 7.6000 - accuracy: 0.5073
# Epoch 12/20
# 343/343 [==============================] - 0s 70us/step - loss: 7.6000 - accuracy: 0.5073
# Epoch 13/20
# 343/343 [==============================] - 0s 72us/step - loss: 7.6000 - accuracy: 0.5073
# Epoch 14/20
# 343/343 [==============================] - 0s 70us/step - loss: 7.6000 - accuracy: 0.5073
# Epoch 15/20
# 343/343 [==============================] - 0s 72us/step - loss: 7.6000 - accuracy: 0.5073
# Epoch 16/20
# 343/343 [==============================] - 0s 68us/step - loss: 7.6000 - accuracy: 0.5073
# Epoch 17/20
# 343/343 [==============================] - 0s 75us/step - loss: 7.6000 - accuracy: 0.5073
# Epoch 18/20
# 343/343 [==============================] - 0s 74us/step - loss: 7.6000 - accuracy: 0.5073
# Epoch 19/20
# 343/343 [==============================] - 0s 71us/step - loss: 7.6000 - accuracy: 0.5073
# Epoch 20/20
# 343/343 [==============================] - 0s 74us/step - loss: 7.6000 - accuracy: 0.5073

# %%
y_keras_pred = model.predict_classes(scaler.transform(X_test))
print('Accuracy: {}'.format(np.sum(y_keras_pred[:,0] == y_test) / float(len(y_test))))
# Out:
# Accuracy: 0.4358974358974359

# %%
import sklearn
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

print(accuracy_score(y_test,y_keras_pred))
print(confusion_matrix(y_test,y_keras_pred))
print(classification_report(y_test,y_keras_pred))
# Out:
# 0.4358974358974359
# [[17  0]
#  [22  0]]
#               precision    recall  f1-score   support
#
#            0       0.44      1.00      0.61        17
#            1       0.00      0.00      0.00        22
#
#     accuracy                           0.44        39
#    macro avg       0.22      0.50      0.30        39
# weighted avg       0.19      0.44      0.26        39
# /home/nitin/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
