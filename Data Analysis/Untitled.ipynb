# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("preprocessed data.xlsx")

# %%
df.head()
# Out:
#    target  tumor size  node status of the tumor  Age of the patient  \
# 0       0           2                         1                  60
# 1       0           1                         1                  55
# 2       0           1                         1                  33
# 3       0           1                         1                  67
# 4       0           1                         1                  47
#
#    tumor grade
# 0            3
# 1            2
# 2            3
# 3            2
# 4            2

# %%
df_1 = df.loc[df["target"]==1]

# %%
df_0 = df.loc[df["target"]==0]

# %% [markdown]
# # Univariate Analysis

# %%
plt.plot(df_1['target'],np.zeros_like(df_1['target']),"o")
plt.plot(df_1['tumor size'],np.zeros_like(df_1['tumor size']),"o")


plt.show()

# %%
plt.plot(df_1['target'],np.zeros_like(df_1['target']),"o")
plt.plot(df_1['Age of the patient'],np.zeros_like(df_1['Age of the patient']),"o")

plt.show()

# %%
plt.plot(df_1['target'],np.zeros_like(df_1['target']),"o")
plt.plot(df_1['tumor grade'],np.zeros_like(df_1['tumor grade']),"o")
plt.show()

# %%
plt.plot(df_1['target'],np.zeros_like(df_1['target']),"o")
plt.plot(df_1['tumor grade'],np.zeros_like(df_1['tumor grade']),"o")
plt.show()

# %% [markdown]
# # Bivaruable anylasis

# %%
sns.FacetGrid(df,hue="target",size=5).map(plt.scatter,"tumor size","node status of the tumor").add_legend();
plt.show()
# Out:
# /home/nitin/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(df,hue="target",size=5).map(plt.scatter,"tumor size","Age of the patient").add_legend();
plt.show()

# %%
sns.FacetGrid(df,hue="target",size=5).map(plt.scatter,"tumor size","tumor grade").add_legend();
plt.show()

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(df,hue="target",size=2)
# Out:
# /home/nitin/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:2079: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df.corr()
# Out:
#                             target  tumor size  node status of the tumor  \
# target                    1.000000   -0.181295                  0.159710
# tumor size               -0.181295    1.000000                 -0.132085
# node status of the tumor  0.159710   -0.132085                  1.000000
# Age of the patient        0.183513   -0.068409                  0.031700
# tumor grade              -0.118765    0.073221                  0.015398
#
#                           Age of the patient  tumor grade
# target                              0.183513    -0.118765
# tumor size                         -0.068409     0.073221
# node status of the tumor            0.031700     0.015398
# Age of the patient                  1.000000    -0.089570
# tumor grade                        -0.089570     1.000000

# %%
sns.pairplot(df)
