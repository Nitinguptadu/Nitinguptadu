# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_info = pd.read_excel('234 file for Candidate.xls')

# %%
df = pd.read_excel('234 file for Candidate.xls',sheet_name='Cancer data')

# %%
df.head()
# Out:
#    sl.no.  0- Good Outcome/no recurrence\n1- Bad Outcome/recurrence  \
# 0       1                                                  0
# 1       2                                                  0
# 2       3                                                  0
# 3       4                                                  0
# 4       5                                                  0
#
#    tumor size  node status of the tumor  Age of the patient  tumor grade  \
# 0           2                         1                  60            3
# 1           1                         1                  55            2
# 2           1                         1                  33            3
# 3           1                         1                  67            2
# 4           1                         1                  47            2
#
#    A%-M  AI-M  A%-C  AI-C  ...   ZD%-M  ZDI-M  ZD%-C  ZDI-C  ZD%-N  ZDI-N  \
# 0     0   2.5    70   2.0  ...      10    1.5     70    2.0      0    0.0
# ...

# %%
df.describe()
# Out:
#            sl.no.  0- Good Outcome/no recurrence\n1- Bad Outcome/recurrence  \
# count  234.000000                                         234.000000
# mean   117.500000                                           0.183761
# std     67.694165                                           0.388119
# min      1.000000                                           0.000000
# 25%     59.250000                                           0.000000
# 50%    117.500000                                           0.000000
# 75%    175.750000                                           0.000000
# max    234.000000                                           1.000000
#
#        tumor size  node status of the tumor  Age of the patient  tumor grade  \
# count  234.000000                234.000000          234.000000   234.000000
# mean     1.944444                  0.705128           48.974359     2.598291
# std      0.525234                  0.670193           10.551294     0.533188
# ...

# %% [markdown]
# # Outlier Analysis

# %%
plt.figure(figsize=(25,75))
sns.boxplot(data=df, orient="h", palette="Set2")

# %%
sns.set(color_codes=True)
sns.lmplot(data=df, x='tumor size', y='Age of the patient', hue='0- Good Outcome/no recurrence\n1- Bad Outcome/recurrence',
                   fit_reg=False, legend=True, legend_out=True,markers=['*',"d"])

# %%
sns.set(color_codes=True)
sns.lmplot(data=df, x='Age of the patient', y='tumor grade', hue='0- Good Outcome/no recurrence\n1- Bad Outcome/recurrence',
                   fit_reg=False, legend=True, legend_out=True,markers=['*',"d"])

# %% [markdown]
# # Outlier Analysis for Good Outcome

# %%
df1 = df[df['0- Good Outcome/no recurrence\n1- Bad Outcome/recurrence']==0]

# %%
plt.figure(figsize=(25,75))
sns.boxplot(data=df1, orient="h", palette="Set2")

# %% [markdown]
# # Outlier Analysis for Bad Outcome

# %%
df2 = df[df['0- Good Outcome/no recurrence\n1- Bad Outcome/recurrence']==1]

# %%
plt.figure(figsize=(25,75))
sns.boxplot(data=df2, orient="h", palette="Set2")

# %% [markdown]
# # User define Function for Removing outliers

# %%
def remove_outlier(df , col_in):
    q1 = df[col_in].quantile(0.25)
    q3 = df[col_in].quantile(0.75)
    value = df[col_in].median()
    iqr = q3-q1
    x = list(df[col_in])
    y = []
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    for i in x:
        if (i < fence_low) or (i > fence_high):
            i = value
            y.append(i)
        else:
            y.append(i)
    df.drop(col_in,axis=1,inplace=True)
    df[col_in] = y

# %% [markdown]
# # User define Function for Removing Zero Values by Mean Value

# %%
def remove_zero_by_mean_value(df,col_in):
    x = df[df[col_in] != 0][col_in].median()
    df[col_in].replace(0,x,inplace=True)

# %% [markdown]
# # Here i have ploted four plots for Measures of Central Tendency

# %% [markdown]
# # Histograms:
# Histograms are normally used to comment on a data set’s distribution.
#
# Using Histogram here I can decide when to replace Zero value using Mean or Median

# %% [markdown]
# # Density plot:
# To see the distribution of the predictor variable.
#
# Ideally, a close to normal distribution (a bell shaped curve), without being skewed to the left or right is preferred.

# %% [markdown]
# # Box plot:
# To spot any outlier observations in the variable.
#
# Having outliers in your predictor can drastically affect the predictions as they can easily affect the direction/slope of the line of best fit.
#
# I have plotted two boxplots
# Right Top - Data with outliers in continous variable
# Right bottom - After removing outliers in individual column

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df['AI-N'])
plt.subplot(222)
sns.boxplot(df['AI-N'])
plt.subplot(223)
sns.kdeplot(df['AI-N'])
remove_outlier(df,'AI-N')
plt.subplot(224)
plt.title("After removing outlier")
sns.boxplot(df['AI-N'])

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df['C%-M'])
plt.subplot(222)
sns.boxplot(df['C%-M'])
plt.subplot(223)
sns.kdeplot(df['C%-M'])
remove_outlier(df,'C%-M')
plt.subplot(224)
plt.title("After removing outlier")
sns.boxplot(df['C%-M'])

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df['CI-M'])
plt.subplot(222)
sns.boxplot(df['CI-M'])
plt.subplot(223)
sns.kdeplot(df['CI-M'])
remove_zero_by_mean_value(df,'CI-M')

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df['F%-M'])
plt.subplot(222)
sns.boxplot(df['F%-M'])
plt.subplot(223)
sns.kdeplot(df['F%-M'])
remove_zero_by_mean_value(df,'F%-M')

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df['F%-C'])
plt.subplot(222)
sns.boxplot(df['F%-C'])
plt.subplot(223)
sns.kdeplot(df['F%-C'])
remove_zero_by_mean_value(df,'F%-C')

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df['K%-M'])
plt.subplot(222)
sns.boxplot(df['K%-M'])
plt.subplot(223)
sns.kdeplot(df['K%-M'])
remove_zero_by_mean_value(df,'K%-M')

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df['K%-N'])
plt.subplot(222)
sns.boxplot(df['K%-N'])
plt.subplot(223)
sns.kdeplot(df['K%-N'])
remove_outlier(df,'K%-N')
plt.subplot(224)
plt.title("After removing outlier")
sns.boxplot(df['K%-N'])

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df['M%-M'])
plt.subplot(222)
sns.boxplot(df['M%-M'])
plt.subplot(223)
sns.kdeplot(df['M%-M'])
remove_zero_by_mean_value(df,'M%-M')

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df['M%-C'])
plt.subplot(222)
sns.boxplot(df['M%-C'])
plt.subplot(223)
sns.kdeplot(df['M%-C'])
remove_outlier(df,'M%-C')
plt.subplot(224)
plt.title("After removing outlier")
sns.boxplot(df['M%-C'])

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df['M%-N'])
plt.subplot(222)
sns.boxplot(df['M%-N'])
plt.subplot(223)
sns.kdeplot(df['M%-N'])
remove_zero_by_mean_value(df,'M%-N')

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df['O%-C'])
plt.subplot(222)
sns.boxplot(df['O%-C'])
plt.subplot(223)
sns.kdeplot(df['O%-C'])
remove_outlier(df,'O%-C')
plt.subplot(224)
plt.title("After removing outlier")
sns.boxplot(df['O%-C'])

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df['P%-N'])
plt.subplot(222)
sns.boxplot(df['P%-N'])
plt.subplot(223)
sns.kdeplot(df['P%-N'])
remove_zero_by_mean_value(df,'P%-N')

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df['R%-M'])
plt.subplot(222)
sns.boxplot(df['R%-M'])
plt.subplot(223)
sns.kdeplot(df['R%-M'])
remove_zero_by_mean_value(df,'R%-M')

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df['R%-C'])
plt.subplot(222)
sns.boxplot(df['R%-C'])
plt.subplot(223)
sns.kdeplot(df['R%-C'])
remove_outlier(df,'R%-C')
plt.subplot(224)
plt.title("After removing outlier")
sns.boxplot(df['R%-C'])

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df['U%-M'])
plt.subplot(222)
sns.boxplot(df['U%-M'])
plt.subplot(223)
sns.kdeplot(df['U%-M'])
remove_zero_by_mean_value(df,'U%-M')

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df['U%-C'])
plt.subplot(222)
sns.boxplot(df['U%-C'])
plt.subplot(223)
sns.kdeplot(df['U%-C'])
remove_outlier(df,'U%-C')
plt.subplot(224)
plt.title("After removing outlier")
sns.boxplot(df['U%-C'])

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df['V%-C'])
plt.subplot(222)
sns.boxplot(df['V%-C'])
plt.subplot(223)
sns.kdeplot(df['V%-C'])
remove_outlier(df,'V%-C')
plt.subplot(224)
plt.title("After removing outlier")
sns.boxplot(df['V%-C'])

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df['W%-M'])
plt.subplot(222)
sns.boxplot(df['W%-M'])
plt.subplot(223)
sns.kdeplot(df['W%-M'])
remove_outlier(df,'W%-M')
plt.subplot(224)
plt.title("After removing outlier")
sns.boxplot(df['W%-M'])

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df['W%-C'])
plt.subplot(222)
sns.boxplot(df['W%-C'])
plt.subplot(223)
sns.kdeplot(df['W%-C'])
remove_outlier(df,'W%-C')
plt.subplot(224)
plt.title("After removing outlier")
sns.boxplot(df['W%-C'])

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df['ZA1%-M'])
plt.subplot(222)
sns.boxplot(df['ZA1%-M'])
plt.subplot(223)
sns.kdeplot(df['ZA1%-M'])
remove_outlier(df,'ZA1%-M')
plt.subplot(224)
plt.title("After removing outlier")
sns.boxplot(df['ZA1%-M'])

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df['ZA1%-C'])
plt.subplot(222)
sns.boxplot(df['ZA1%-C'])
plt.subplot(223)
sns.kdeplot(df['ZA1%-C'])
remove_outlier(df,'ZA1%-C')
plt.subplot(224)
plt.title("After removing outlier")
sns.boxplot(df['ZA1%-C'])

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df['ZB%-M'])
plt.subplot(222)
sns.boxplot(df['ZB%-M'])
plt.subplot(223)
sns.kdeplot(df['ZB%-M'])
remove_zero_by_mean_value(df,'ZB%-M')

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df['ZB%-C'])
plt.subplot(222)
sns.boxplot(df['ZB%-C'])
plt.subplot(223)
sns.kdeplot(df['ZB%-C'])
remove_outlier(df,'ZB%-C')
plt.subplot(224)
plt.title("After removing outlier")
sns.boxplot(df['ZB%-C'])

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df['ZB%-N'])
plt.subplot(222)
sns.boxplot(df['ZB%-N'])
plt.subplot(223)
sns.kdeplot(df['ZB%-N'])
remove_zero_by_mean_value(df,'ZB%-N')

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df['ZC%-C'])
plt.subplot(222)
sns.boxplot(df['ZC%-C'])
plt.subplot(223)
sns.kdeplot(df['ZC%-C'])
remove_outlier(df,'ZC%-C')
plt.subplot(224)
plt.title("After removing outlier")
sns.boxplot(df['ZC%-C'])

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df[' ZD%-M'])
plt.subplot(222)
sns.boxplot(df[' ZD%-M'])
plt.subplot(223)
sns.kdeplot(df[' ZD%-M'])
remove_zero_by_mean_value(df,' ZD%-M')

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df['ZD%-C'])
plt.subplot(222)
sns.boxplot(df['ZD%-C'])
plt.subplot(223)
sns.kdeplot(df['ZD%-C'])
remove_outlier(df,'ZD%-C')
plt.subplot(224)
plt.title("After removing outlier")
sns.boxplot(df['ZD%-C'])

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df['ZF2%-C'])
plt.subplot(222)
sns.boxplot(df['ZF2%-C'])
plt.subplot(223)
sns.kdeplot(df['ZF2%-C'])
remove_zero_by_mean_value(df,'ZF2%-C')

# %%
plt.figure(1,figsize=(15,15))
plt.subplot(221)   
plt.hist(df['ZF2%-N'])
plt.subplot(222)
sns.boxplot(df['ZF2%-N'])
plt.subplot(223)
sns.kdeplot(df['ZF2%-N'])
remove_zero_by_mean_value(df,'ZF2%-N')

# %%
correlations = df.corr(method='pearson')
print(correlations)
# Out:
#                                                       sl.no.  \
# sl.no.                                              1.000000
# 0- Good Outcome/no recurrence\n1- Bad Outcome/r...  0.670810
# tumor size                                          0.157224
# node status of the tumor                            0.434074
# Age of the patient                                  0.046154
# ...                                                      ...
# ZA1%-M                                              0.045361
# ZA1%-C                                             -0.005592
# ZB%-C                                               0.038453
# ZC%-C                                               0.044397
# ZD%-C                                              -0.037953
#
#                                                     0- Good Outcome/no recurrence\n1- Bad Outcome/recurrence  \
# sl.no.                                                                                       0.670810
# ...

# %%
sns.heatmap(correlations)

# %%
df.to_excel("preprocessed data.xlsx")
# Out:
# '/home/nitin/Desktop/onco labs/Machine learning soloution'
